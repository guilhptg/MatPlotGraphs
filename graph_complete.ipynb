# %%
import matplotlib.pyplot as plt

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

fig, ax = plt.subplots()

ax.plot(meses, vendas)
ax.set_xlabel('Meses')
ax.set_ylabel('Vendas')
ax.set_title('Evolução de vendas ao longo do ano.')


plt.show()

# %%
# Data
produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

fix, ax = plt.subplots()

ax.bar(produtos, quantidades)
ax.set_xlabel('Produtos')
ax.set_ylabel('Quantidades')
ax.set_title('Quantidade de vendas por produtos')


plt.show()

# %%
# Data

categorias = ['Eletronicos', 'Roupas', 'Alimentos', 'Livros']
quantidades_pizza = [45, 30, 15, 10]
destaque = [0.1, 0.05, 0.05, 0.05]

fig, ax = plt.subplots()


ax.pie(quantidades_pizza, labels=categorias, explode=destaque, autopct='%.2f')
ax.set_title('Categorias de produtos vendidos')


plt.show()

# %%
# Data

anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

fig, ax = plt.subplots()

ax.bar(anos, vendas_online, label='Online')
ax.bar(anos, vendas_loja, bottom=vendas_online, label='Loja')

ax.set_xticks(anos)

ax.legend()

ax.set_xlabel('Ano')
ax.set_ylabel('Vendas em milhões de Reais')
ax.set_title('Vendas - Online X Loja')



plt.show()

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(16,10))

# grafico 1 - linhas
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]


axs[0][0].plot(meses, vendas)
axs[0][0].set_xlabel('Mês')
axs[0][0].set_ylabel('Vendas ( em milhares de reais )')
axs[0][0].set_title('Crescimento de vendas ao longo do ano')

# grafico 2 - barras 


axs[0][1].bar(produtos, quantidades)
axs[0][1].set_xlabel('Produtos')
axs[0][1].set_ylabel('Quantidades')
axs[0][1].set_title('Quantidade de vendas por produtos')


# grafico 3 - pizza

axs[1][0].pie(quantidades_pizza, labels=categorias, explode=destaque, autopct='%.2f')
axs[1][0].set_title('Categorias de produtos vendidos')

# grafico 4 - barras empilhadas

axs[1][1].bar(anos, vendas_online, label='Online')
axs[1][1].bar(anos, vendas_loja, bottom=vendas_online, label='Loja')
axs[1][1].set_xticks(anos)
axs[1][1].legend()
axs[1][1].set_xlabel('Ano')
axs[1][1].set_ylabel('Vendas em milhões de Reais')
axs[1][1].set_title('Vendas - Online X Loja')


# ajusstes finais
fig.suptitle('Evolução de vendas', fontsize=16)

plt.show()

# %% [markdown]
# # Moisaico

# %%
moisaico = 'A;B;C;D'
fig = plt.figure(figsize=(16,10))
mosa = fig.subplot_mosaic(moisaico)
print(mosa)
plt.show()
# Out:
# {'A': <Axes: label='A'>, 'B': <Axes: label='B'>, 'C': <Axes: label='C'>, 'D': <Axes: label='D'>}

# %%
moisaico = 'AA;BB;CD'
fig = plt.figure(figsize=(14,10))
# ESPAÇO
espacamento = {'wspace': 0.3, 'hspace':0.35}
axs = fig.subplot_mosaic(moisaico, gridspec_kw=espacamento)


# grafico 1 - linhas
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]


axs['A'].plot(meses, vendas)
axs['A'].set_xlabel('Mês')
axs['A'].set_ylabel('Vendas ( em milhares de reais )')
axs['A'].set_title('Crescimento de vendas ao longo do ano')

# grafico 2 - barras 


axs['B'].bar(produtos, quantidades)
axs['B'].set_ylabel('Quantidades')
axs['B'].set_title('Quantidade de vendas por produtos')


# grafico 3 - pizza

axs['C'].pie(quantidades_pizza, labels=categorias, explode=destaque, autopct='%.2f')
axs['C'].set_title('Categorias de produtos vendidos')

# grafico 4 - barras empilhadas

axs['D'].bar(anos, vendas_online, label='Online')
axs['D'].bar(anos, vendas_loja, bottom=vendas_online, label='Loja')
axs['D'].set_xticks(anos)
axs['D'].legend()
axs['D'].set_xlabel('Ano')
axs['D'].set_ylabel('Vendas em milhões de Reais')
axs['D'].set_title('Vendas - Online X Loja')


# ajusstes finais
fig.suptitle('Evolução de vendas', fontsize=16)

plt.show()

# %%
moisaico = 'AA;BB;CD'
fig = plt.figure(figsize=(16,10))
axs = fig.subplot_mosaic(moisaico)

plt.show()
