# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)

colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

df_churn.head()
# Out:
#       genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0   Feminino   Não          Sim             Não                 1
# 1  Masculino   Não          Não             Não                34
# 2  Masculino   Não          Não             Não                 2
# 3  Masculino   Não          Não             Não                45
# 4   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# 0              Não              Não              DSL               Não
# 1              Sim              Não              DSL               Sim
# 2              Sim              Não              DSL               Sim
# 3              Não              Não              DSL               Sim
# 4              Sim              Não     Fibra optica               Não
#
#   servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# 0            Sim                          Não                     Não
# 1            Não                          Sim                     Não
# 2            Sim                          Não                     Não
# 3            Não                          Sim                     Sim
# 4            Não                          Não                     Não
#
#   streaming_tv streaming_filmes contrato fatura_digital forma_pagamento  \
# 0          Não              Não   Mensal            Sim          Boleto
# 1          Não              Não    Anual            Não          Cheque
# 2          Não              Não   Mensal            Sim          Cheque
# 3          Não              Não    Anual            Não   Transferencia
# 4          Não              Não   Mensal            Sim          Boleto
#
#    valor_mensal  total_gasto churn
# 0         29.85        29.85   Não
# 1         56.95      1889.50   Não
# 2         53.85       108.15   Sim
# 3         42.30      1840.75   Não
# 4         70.70       151.65   Sim

# %% [markdown]
# ### Histogram

# %%
df_churn[colunas_numericas].hist(layout=(1, 3), figsize=(14,7), bins=10);

# %%
df_churn['meses_na_empresa'].value_counts(bins=10).sort_index()
# Out:
# (-0.073, 7.2]    1612
# (7.2, 14.4]       759
# (14.4, 21.6]      570
# (21.6, 28.8]      556
# (28.8, 36.0]      545
# (36.0, 43.2]      444
# (43.2, 50.4]      452
# (50.4, 57.6]      495
# (57.6, 64.8]      501
# (64.8, 72.0]     1109
# Name: count, dtype: int64

# %%
sns.set_theme(style='dark', palette='bright', context='notebook')

sns.histplot(x='meses_na_empresa', data=df_churn, hue='contrato', multiple='stack');

# %% [markdown]
# ### With Seaborn and MatPlotLib

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(14,7), tight_layout=True)

for i, coluna in enumerate(colunas_numericas):
    sns.histplot(x=coluna, data=df_churn, hue='contrato', multiple='stack', ax=axs[i])
    

plt.show()

# %% [markdown]
# ## KDE Graph

# %%
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)

colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 6), tight_layout=True)

for i, coluna in enumerate(colunas_numericas):
    sns.kdeplot(x=coluna, data=df_churn, hue='contrato', ax=axs[i], fill=True)

plt.show()

# %%
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)

colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 6), tight_layout=True)

for i, coluna in enumerate(colunas_numericas):
    sns.histplot(x=coluna, data=df_churn, hue='churn', multiple='stack', ax=axs[i], fill=True)

plt.show()

# %%
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)

colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 6), tight_layout=True)

for i, coluna in enumerate(colunas_numericas):
    sns.kdeplot(x=coluna, data=df_churn, hue='churn', ax=axs[i], fill=True)

plt.show()

# %%
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)

colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 6), tight_layout=True)

for i, coluna in enumerate(colunas_numericas):
    sns.kdeplot(x=coluna, data=df_churn, hue='churn', ax=axs[i], fill=True)
    legenda = axs[i].get_legend()
    legenda.remove()

rotulos = [text.get_text() for text in legenda.get_texts()]

fig.legend(handles=legenda.legend_handles, labels=rotulos, loc='upper center', ncols=2, title='Churn', bbox_to_anchor=(0.5, 0.95))

fig.suptitle('Empresa X, no Ano XXXX\n\n', fontsize=16)
plt.show()

# %% [markdown]
# ### FacetGrid

# %%
import seaborn as sns

# Data
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)


colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')



g = sns.FacetGrid(df_churn, col='contrato')

g.map_dataframe(sns.histplot, x='meses_na_empresa')

plt.show()

# %%
import seaborn as sns

# Data
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)


colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')



g = sns.FacetGrid(df_churn, col='contrato', hue='churn')

g.map_dataframe(sns.histplot, x='meses_na_empresa')

plt.show()

# %%
import seaborn as sns
sns.set_theme(style='darkgrid', context='notebook', palette='deep')

# Data
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)


colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')



g = sns.FacetGrid(df_churn, col='contrato', hue='churn', row='churn')

g.map_dataframe(sns.histplot, x='meses_na_empresa')

plt.show()

# %%
import seaborn as sns
sns.set_theme(style='whitegrid', context='notebook', palette='deep')

# Data
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)


colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')



g = sns.FacetGrid(df_churn, col='contrato', hue='churn')
g.map_dataframe(sns.scatterplot, x='meses_na_empresa', y='total_gasto')
g.add_legend()

plt.show()

# %% [markdown]
# ##### baixa do contrato bianual e alta do Churn
#
#
# ## PairPlot

# %%
sns.pairplot(data=df_churn, hue='churn')

# %%
df_churn = pd.read_csv('churn_clientes.csv')
df_churn = df_churn.drop(columns='id_cliente', axis=1)

colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 4), tight_layout=True, sharey=True)

for i, coluna in enumerate(colunas_numericas):
        sns.boxplot(x=coluna, y='churn', data=df_churn, ax=axs[i], hue='churn')

fig.suptitle('Empresa')
plt.show()

# %%
print(len(colunas_categoricas))
print(colunas_categoricas)
# Out:
# 16
# Index(['genero', 'idoso', 'tem_parceiro', 'tem_dependentes',
#        'servico_telefone', 'multiplas_linhas', 'servico_internet',
#        'servico_seguranca', 'servico_backup', 'servico_protecao_equipamento',
#        'servico_suporte_tecnico', 'streaming_tv', 'streaming_filmes',
#        'contrato', 'fatura_digital', 'forma_pagamento'],
#       dtype='object')

# %%
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(14,14), sharey=True, tight_layout=True)


for i, coluna in enumerate(colunas_categoricas):
    h = sns.histplot(x=coluna, data=df_churn, hue='churn', multiple='fill', ax=axs.flat[i], stat='percent', shrink=0.8)
    h.tick_params(axis='x', labelrotation=35)
    legenda = h.get_legend()
    legenda.remove()


rotulos = [text.get_text() for text in legenda.get_texts()]

fig.legend(handles=legenda.legend_handles, labels=rotulos, loc='upper center', ncols=2, title='Churn', bbox_to_anchor=(0.50, 0.965))


fig.suptitle('Churn por variável categórica \n\n')
fig.align_labels()


plt.show()

# %%
print(list(axs.flat))
# Out:
# [<Axes: xlabel='genero', ylabel='Percent'>, <Axes: xlabel='idoso', ylabel='Percent'>, <Axes: xlabel='tem_parceiro', ylabel='Percent'>, <Axes: xlabel='tem_dependentes', ylabel='Percent'>, <Axes: xlabel='servico_telefone', ylabel='Percent'>, <Axes: xlabel='multiplas_linhas', ylabel='Percent'>, <Axes: xlabel='servico_internet', ylabel='Percent'>, <Axes: xlabel='servico_seguranca', ylabel='Percent'>, <Axes: xlabel='servico_backup', ylabel='Percent'>, <Axes: xlabel='servico_protecao_equipamento', ylabel='Percent'>, <Axes: xlabel='servico_suporte_tecnico', ylabel='Percent'>, <Axes: xlabel='streaming_tv', ylabel='Percent'>, <Axes: xlabel='streaming_filmes', ylabel='Percent'>, <Axes: xlabel='contrato', ylabel='Percent'>, <Axes: xlabel='fatura_digital', ylabel='Percent'>, <Axes: xlabel='forma_pagamento', ylabel='Percent'>]

# %%
from matplotlib.ticker import PercentFormatter


fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(14,16), sharey=True)


for i, coluna in enumerate(colunas_categoricas):
    h = sns.histplot(x=coluna, data=df_churn, hue='churn', multiple='fill', ax=axs.flat[i], stat='percent', shrink=0.8)
    h.tick_params(axis='x', labelrotation=35)

    h.yaxis.set_major_formatter(PercentFormatter(1))
    h.set_ylabel([])
    legenda = h.get_legend()
    legenda.remove()

    for barra in h.containers:
        h.bar_label(barra, label_type='center', labels=[f'{parte.get_height():.1%}' for parte in barra], color='white', weight='bold', fontsize=10)

rotulos = [text.get_text() for text in legenda.get_texts()]

fig.legend(handles=legenda.legend_handles, labels=rotulos, loc='upper center', ncols=2, title='Churn', bbox_to_anchor=(0.50, 0.965))


fig.suptitle('Churn por variável categórica \n\n\n')
fig.align_labels()

plt.subplots_adjust(wspace=0.4, hspace=0.4, top=0.925)

plt.show()

# %%
sns.boxplot(x='servico_internet', y='valor_mensal', data=df_churn, hue='churn');

# %%
df_churn['churn'].nunique()
# Out:
# 2

# %%
df_churn['churn'] = df_churn['churn'].replace({'Sim': 1, 'Não': 0})
df_churn.head()
# Out:
#       genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0   Feminino   Não          Sim             Não                 1
# 1  Masculino   Não          Não             Não                34
# 2  Masculino   Não          Não             Não                 2
# 3  Masculino   Não          Não             Não                45
# 4   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# 0              Não              Não              DSL               Não
# 1              Sim              Não              DSL               Sim
# 2              Sim              Não              DSL               Sim
# 3              Não              Não              DSL               Sim
# 4              Sim              Não     Fibra optica               Não
#
#   servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# 0            Sim                          Não                     Não
# 1            Não                          Sim                     Não
# 2            Sim                          Não                     Não
# 3            Não                          Sim                     Sim
# 4            Não                          Não                     Não
#
#   streaming_tv streaming_filmes contrato fatura_digital forma_pagamento  \
# 0          Não              Não   Mensal            Sim          Boleto
# 1          Não              Não    Anual            Não          Cheque
# 2          Não              Não   Mensal            Sim          Cheque
# 3          Não              Não    Anual            Não   Transferencia
# 4          Não              Não   Mensal            Sim          Boleto
#
#    valor_mensal  total_gasto  churn
# 0         29.85        29.85      0
# 1         56.95      1889.50      0
# 2         53.85       108.15      1
# 3         42.30      1840.75      0
# 4         70.70       151.65      1

# %%
df_dummies = pd.get_dummies(df_churn)
df_dummies.head()
# Out:
#    meses_na_empresa  valor_mensal  total_gasto  churn  genero_Feminino  \
# 0                 1         29.85        29.85      0             True
# 1                34         56.95      1889.50      0            False
# 2                 2         53.85       108.15      1            False
# 3                45         42.30      1840.75      0            False
# 4                 2         70.70       151.65      1             True
#
#    genero_Masculino  idoso_Não  idoso_Sim  tem_parceiro_Não  tem_parceiro_Sim  \
# 0             False       True      False             False              True
# 1              True       True      False              True             False
# 2              True       True      False              True             False
# 3              True       True      False              True             False
# 4             False       True      False              True             False
#
#    ...  streaming_filmes_Sim  contrato_Anual  contrato_Bianual  \
# 0  ...                 False           False             False
# 1  ...                 False            True             False
# 2  ...                 False           False             False
# 3  ...                 False            True             False
# 4  ...                 False           False             False
#
#    contrato_Mensal  fatura_digital_Não  fatura_digital_Sim  \
# 0             True               False                True
# 1            False                True               False
# 2             True               False                True
# 3            False                True               False
# 4             True               False                True
#
#    forma_pagamento_Boleto  forma_pagamento_Cartao de credito  \
# 0                    True                              False
# 1                   False                              False
# 2                   False                              False
# 3                   False                              False
# 4                    True                              False
#
#    forma_pagamento_Cheque  forma_pagamento_Transferencia
# 0                   False                          False
# 1                    True                          False
# 2                    True                          False
# 3                   False                           True
# 4                   False                          False
#
# [5 rows x 40 columns]

# %%
churn_corr = df_dummies.corr()['churn'].sort_values(ascending=False)
print(churn_corr)
# Out:
# churn                                1.000000
# contrato_Mensal                      0.405103
# servico_internet_Fibra optica        0.308020
# forma_pagamento_Boleto               0.301919
# valor_mensal                         0.193356
# fatura_digital_Sim                   0.191825
# servico_seguranca_Não                0.171226
# servico_suporte_tecnico_Não          0.164674
# tem_dependentes_Não                  0.164221
# idoso_Sim                            0.150889
# tem_parceiro_Não                     0.150448
# servico_backup_Não                   0.082255
# servico_protecao_equipamento_Não     0.066160
# streaming_tv_Sim                     0.063228
# streaming_filmes_Sim                 0.061382
# multiplas_linhas_Sim                 0.040102
# servico_telefone_Sim                 0.011942
# genero_Feminino                      0.008612
# genero_Masculino                    -0.008612
# servico_telefone_Não                -0.011942
# multiplas_linhas_Não                -0.040102
# streaming_filmes_Não                -0.061382
# streaming_tv_Não                    -0.063228
# servico_protecao_equipamento_Sim    -0.066160
# servico_backup_Sim                  -0.082255
# forma_pagamento_Cheque              -0.091683
# forma_pagamento_Transferencia       -0.117937
# servico_internet_DSL                -0.124214
# forma_pagamento_Cartao de credito   -0.134302
# tem_parceiro_Sim                    -0.150448
# idoso_Não                           -0.150889
# tem_dependentes_Sim                 -0.164221
# servico_suporte_tecnico_Sim         -0.164674
# servico_seguranca_Sim               -0.171226
# contrato_Anual                      -0.177820
# fatura_digital_Não                  -0.191825
# total_gasto                         -0.199037
# servico_internet_Não                -0.227890
# contrato_Bianual                    -0.302253
# meses_na_empresa                    -0.352229
# Name: churn, dtype: float64

# %%
df_dummies.corr().style.format(precision=2).background_gradient(cmap='coolwarm_r', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T
{
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_cebb6_row0_col10, #T_cebb6_row2_col34, #T_cebb6_row5_col33, #T_cebb6_row6_col34, #T_cebb6_row10_col0, #T_cebb6_row13_col33, #T_cebb6_row14_col34, #T_cebb6_row15_col21, #T_cebb6_row21_col15, #T_cebb6_row33_col5, #T_cebb6_row33_col13, #T_cebb6_row34_col2, #T_cebb6_row34_col6, #T_cebb6_row34_col14 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_cebb6_row0_col11, #T_cebb6_row1_col4, #T_cebb6_row3_col10, #T_cebb6_row3_col13, #T_cebb6_row3_col20, #T_cebb6_row3_col24, #T_cebb6_row3_col26, #T_cebb6_row3_col28, #T_cebb6_row3_col30, #T_cebb6_row3_col33, #T_cebb6_row3_col37, #T_cebb6_row3_col39, #T_cebb6_row4_col1, #T_cebb6_row4_col9, #T_cebb6_row4_col14, #T_cebb6_row4_col16, #T_cebb6_row4_col21, #T_cebb6_row4_col25, #T_cebb6_row4_col27, #T_cebb6_row4_col29,

# %%
print(type(churn_corr))
# Out:
# <class 'pandas.core.series.Series'>

# %%
churn_corr[1:].plot(kind='bar', figsize=(16,5))
# Out:
# <Axes: >

# %%
barras_churn = sns.barplot(x=churn_corr[1:].index, y=churn_corr[1:].values, palette='plasma');
# Out:
# C:\Users\guik1\AppData\Local\Temp\ipykernel_10820\371677654.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barras_churn = sns.barplot(x=churn_corr[1:].index, y=churn_corr[1:].values, palette='plasma');

# %%
fig, ax = plt.subplots(figsize=(16,5))

b = sns.barplot(x=churn_corr[1:].index, y=churn_corr[1:].values, palette='plasma', ax=ax)

b.tick_params(axis='x', rotation=5)

plt.show()
# Out:
# C:\Users\guik1\AppData\Local\Temp\ipykernel_10820\3018596911.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.barplot(x=churn_corr[1:].index, y=churn_corr[1:].values, palette='plasma', ax=ax)

# %%
fig, ax = plt.subplots(figsize=(16,5))

b = sns.kdeplot(x=churn_corr[1:].index, y=churn_corr[1:].values, palette='plasma', ax=ax)

b.tick_params(axis='x', rotation=5)

plt.show()
# Out:
# C:\Users\guik1\AppData\Local\Temp\ipykernel_10820\2539687350.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   b = sns.kdeplot(x=churn_corr[1:].index, y=churn_corr[1:].values, palette='plasma', ax=ax)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 3
#       1 fig, ax = plt.subplots(figsize=(16,5))
# ----> 3 b = sns.kdeplot(x=churn_corr[1:].index, y=churn_corr[1:].values, palette='plasma', ax=ax)
#       5 b.tick_params(axis='x', rotation=5)
#       7 plt.show()
#
# File c:\Users\guik1\OneDrive\Documentos\MyRepositoryes\MatPlotGraphs\.venv\Lib\site-packages\seaborn\distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1681 method = ax.fill_between if fill else ax.plot
#    1682 color = _default_color(method, hue, color, kwargs)
#
# File c:\Users\guik1\OneDrive\Documentos\MyRepositoryes\MatPlotGraphs\.venv\Lib\site-packages\seaborn\_base.py:1084, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1079     if var_type not in allowed_types:
#    1080         err = (
#    1081             f"The {var} variable is {var_type}, but one of "
#    1082             f"{allowed_types} is required"
#    1083         )
# -> 1084         raise TypeError(err)
#    1086 # -- Get axis objects for each row in plot_data for type conversions and scaling
#    1088 facet_dim = {"x": "col", "y": "row"}
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required
